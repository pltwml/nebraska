# %%
import os, time
import numpy as np

# %%
#base_dir = '/content/drive/My Drive/data/cats_dogs_small'

base_dir = '/Users/g0d/dev/data/DL2018/cats_dogs_small'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir = os.path.join(base_dir, 'test')

train_cats_dir = os.path.join(train_dir, 'cats')
train_dogs_dir = os.path.join(train_dir, 'dogs')

# %%
import h5py
from PIL import Image

fileName = 'data.h5'
numOfSamples = 10000
with h5py.File(fileName, "w") as out:
  out.create_dataset("X_train",(numOfSamples,256,256,3),dtype='u1')
  out.create_dataset("Y_train",(numOfSamples,1,1),dtype='u1')      
  out.create_dataset("X_dev",(numOfSamples,256,256,3),dtype='u1')
  out.create_dataset("Y_dev",(numOfSamples,1,1),dtype='u1')      
  out.create_dataset("X_test",(numOfSamples,256,256,3),dtype='u1')
  out.create_dataset("Y_test",(numOfSamples,1,1),dtype='u1')

# %%
# !rm data.h5

# %%
# !ls
# Out:
# DataToHDF5Transform.ipynb

# %%
from keras.preprocessing import image

fnames = [os.path.join(train_cats_dir, fname) for 
         fname in os.listdir(train_cats_dir)]

img_path = fnames[999]

img = image.load_img(img_path, target_size=(150, 150))

# %%
img_path
# Out:
# '/Users/g0d/dev/data/DL2018/cats_dogs_small/train/cats/cat.793.jpg'

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0xB2E4F5DA0>

# %%
with h5py.File(fileName, "a") as out:
   img = Image.open(img_path)      # X_train_1.jpg is 256 x 256 RGB image
   out['X_train'] = np.asarray(img)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-2959ce46d3f4> in <module>
#       1 with h5py.File(fileName, "a") as out:
#       2    img = Image.open(img_path)      # X_train_1.jpg is 256 x 256 RGB image
# ----> 3    out['X_train'] = np.asarray(img)
#
# ~/anaconda3/envs/pyt36/lib/python3.6/site-packages/h5py/_hl/group.py in __setitem__(self, name, obj)
#     300             else:
#     301                 ds = self.create_dataset(None, data=obj, dtype=base.guess_dtype(obj))
# --> 302                 h5o.link(ds.id, self.id, name, lcpl=lcpl)
#     303
#     304         if do_link:
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.link()
#
# RuntimeError: Unable to create link (name already exists)
